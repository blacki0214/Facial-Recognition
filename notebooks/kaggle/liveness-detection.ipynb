# %%
import os, cv2, pandas as pd
from tqdm import tqdm

DATASET_PATH = "/kaggle/input/liveness-detection-zalo-2022"
VIDEO_DIR = os.path.join(DATASET_PATH, "train/train/videos")
LABEL_FILE = os.path.join(DATASET_PATH, "train/train/label.csv")
OUTPUT_PATH = "/kaggle/working/liveness_frames"

# Make output folders
os.makedirs(os.path.join(OUTPUT_PATH, "real"), exist_ok=True)
os.makedirs(os.path.join(OUTPUT_PATH, "fake"), exist_ok=True)

# Read label file
labels = pd.read_csv(LABEL_FILE)
print(labels.head())
# Out:
#    fname  liveness_score
# 0  1.mp4               0
# 1  2.mp4               1
# 2  3.mp4               1
# 3  5.mp4               0
# 4  7.mp4               1

# %%
def extract_frames(video_path, label, save_dir):
    cap = cv2.VideoCapture(video_path)
    total = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    frame_ids = [int(total*x) for x in [0.2, 0.5, 0.8]]  # pick 3 frames
    count = 0
    for fid in frame_ids:
        cap.set(cv2.CAP_PROP_POS_FRAMES, fid)
        ret, frame = cap.read()
        if ret:
            name = f"{label}_{os.path.basename(video_path).split('.')[0]}_{count}.jpg"
            cv2.imwrite(os.path.join(save_dir, name), frame)
            count += 1
    cap.release()

for _, row in tqdm(labels.iterrows(), total=len(labels)):
    video_path = os.path.join(VIDEO_DIR, row['fname'])
    if not os.path.exists(video_path): continue
    label = int(row['liveness_score'])
    save_dir = os.path.join(OUTPUT_PATH, "real" if label == 1 else "fake")
    extract_frames(video_path, label, save_dir)
# Out:
# 100%|██████████| 1168/1168 [12:58<00:00,  1.50it/s]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam

IMG_SIZE = (160, 160)
train_dir = "/kaggle/working/liveness_frames"

datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)

train_gen = datagen.flow_from_directory(
    train_dir, target_size=IMG_SIZE, batch_size=32,
    class_mode='binary', subset='training'
)

val_gen = datagen.flow_from_directory(
    train_dir, target_size=IMG_SIZE, batch_size=32,
    class_mode='binary', subset='validation'
)

model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(160,160,3)),
    BatchNormalization(), MaxPooling2D(2,2),
    Conv2D(64, (3,3), activation='relu'),
    BatchNormalization(), MaxPooling2D(2,2),
    Conv2D(128, (3,3), activation='relu'),
    BatchNormalization(), MaxPooling2D(2,2),
    Flatten(), Dropout(0.4),
    Dense(128, activation='relu'),
    Dense(1, activation='sigmoid')
])

model.compile(optimizer=Adam(1e-4),
              loss='binary_crossentropy',
              metrics=['accuracy'])

callbacks = [
    EarlyStopping(patience=3, restore_best_weights=True),
    ModelCheckpoint("/kaggle/working/liveness_detector_zalo.h5", save_best_only=True)
]

history = model.fit(train_gen, validation_data=val_gen, epochs=10, callbacks=callbacks)
# Out:
# 2025-11-17 19:08:15.292598: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763406495.456821      39 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763406495.505960      39 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Found 2804 images belonging to 2 classes.
# Found 700 images belonging to 2 classes.
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# I0000 00:00:1763406507.059594      39 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1763406507.060267      39 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1763406513.296207    4793 service.cc:148] XLA service 0x79f9f4002950 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1763406513.296898    4793 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1763406513.296920    4793 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1763406513.825959    4793 cuda_dnn.cc:529] Loaded cuDNN version 90300
#  1/88 ━━━━━━━━━━━━━━━━━━━━ 14:37 10s/step - accuracy: 0.3438 - loss: 2.3039
# I0000 00:00:1763406518.915403    4793 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 44s 384ms/step - accuracy: 0.6785 - loss: 1.0088 - val_accuracy: 0.4886 - val_loss: 1.0243
# Epoch 2/10
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 29s 333ms/step - accuracy: 0.9418 - loss: 0.1651 - val_accuracy: 0.6657 - val_loss: 0.6218
# Epoch 3/10
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 29s 334ms/step - accuracy: 0.9798 - loss: 0.0691 - val_accuracy: 0.6171 - val_loss: 1.0294
# Epoch 4/10
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 29s 325ms/step - accuracy: 0.9899 - loss: 0.0367 - val_accuracy: 0.6471 - val_loss: 1.2467
# Epoch 5/10
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 29s 324ms/step - accuracy: 0.9946 - loss: 0.0267 - val_accuracy: 0.6543 - val_loss: 1.2590

# %%
# Re-export model in universal, forward-compatible format
import keras

model.save("/kaggle/working/liveness_detector_zalo.keras")

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report

def predict_video(video_path):
    cap = cv2.VideoCapture(video_path)
    preds = []

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        # sample every 5 frames
        if int(cap.get(cv2.CAP_PROP_POS_FRAMES)) % 5 == 0:
            frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            frame = cv2.resize(frame, IMG_SIZE)
            frame = frame / 255.0
            frame = np.expand_dims(frame, axis=0)
            pred = model.predict(frame, verbose=0)[0][0]
            preds.append(pred)

    cap.release()

    avg = np.mean(preds)
    return avg, 1 if avg >= 0.5 else 0  # 1=Real, 0=Fake


def evaluate_folder(folder, label):
    """
    folder: path to videos
    label: true label (0=Fake, 1=Real)
    """
    y_true = []
    y_pred = []
    files = sorted(os.listdir(folder))

    print(f"\n=== Evaluating {folder} ===")

    for f in files:
        if f.endswith(".mp4"):
            prob, pred = predict_video(os.path.join(folder, f))
            print(f"{f} → Prob={prob:.4f}, Pred={pred}, True={label}")

            y_true.append(label)
            y_pred.append(pred)

    return y_true, y_pred


# ---- Edit these according to your dataset ----
fake_folder = "/kaggle/input/liveness-detection-zalo-2022/public_test/public/videos"       # change if needed
real_folder = "/kaggle/input/liveness-detection-zalo-2022/public_test_2/public_test_2/videos"

y_true_fake, y_pred_fake = evaluate_folder(fake_folder, 0)
y_true_real, y_pred_real = evaluate_folder(real_folder, 1)

y_true = y_true_fake + y_true_real
y_pred = y_pred_fake + y_pred_real


# ------------------ Classification Report ------------------
print("\n=== Classification Report ===")
print(classification_report(y_true, y_pred, target_names=["Fake", "Real"]))

# ------------------ Confusion Matrix -----------------------
cm = confusion_matrix(y_true, y_pred)
print("\n=== Confusion Matrix ===")
print(cm)
# Out:
# === Evaluating /kaggle/input/liveness-detection-zalo-2022/public_test/public/videos ===
# 0.mp4 → Prob=0.4452, Pred=0, True=0
# 100.mp4 → Prob=0.8813, Pred=1, True=0
# 1001.mp4 → Prob=0.6689, Pred=1, True=0
# 1005.mp4 → Prob=0.8564, Pred=1, True=0
# 1022.mp4 → Prob=0.3484, Pred=0, True=0
# 1023.mp4 → Prob=0.6515, Pred=1, True=0
# 1045.mp4 → Prob=0.6973, Pred=1, True=0
# 1048.mp4 → Prob=0.8133, Pred=1, True=0
# 1049.mp4 → Prob=0.4794, Pred=0, True=0
# 1062.mp4 → Prob=0.5871, Pred=1, True=0
# 1079.mp4 → Prob=0.5946, Pred=1, True=0
# 1092.mp4 → Prob=0.2268, Pred=0, True=0
# 1102.mp4 → Prob=0.4032, Pred=0, True=0
# 1116.mp4 → Prob=0.9059, Pred=1, True=0
# 1122.mp4 → Prob=0.8962, Pred=1, True=0
# 1132.mp4 → Prob=0.6542, Pred=1, True=0
# 1133.mp4 → Prob=0.3957, Pred=0, True=0
# 1141.mp4 → Prob=0.4101, Pred=0, True=0
# 1151.mp4 → Prob=0.5560, Pred=1, True=0
# 1155.mp4 → Prob=0.3853, Pred=0, True=0
# 1156.mp4 → Prob=0.3823, Pred=0, True=0
# 1159.mp4 → Prob=0.4038, Pred=0, True=0
# 1178.mp4 → Prob=0.3753, Pred=0, True=0
# 118.mp4 → Prob=0.7846, Pred=1, True=0
# 1180.mp4 → Prob=0.6594, Pred=1, True=0
# 1187.mp4 → Prob=0.1842, Pred=0, True=0
# 1201.mp4 → Prob=0.9019, Pred=1, True=0
# 1208.mp4 → Prob=0.6206, Pred=1, True=0
# 121.mp4 → Prob=0.9122, Pred=1, True=0
# 1214.mp4 → Prob=0.8359, Pred=1, True=0
# 1220.mp4 → Prob=0.4015, Pred=0, True=0
# 1224.mp4 → Prob=0.7389, Pred=1, True=0
# 1227.mp4 → Prob=0.6506, Pred=1, True=0
# 123.mp4 → Prob=0.5818, Pred=1, True=0
# 1239.mp4 → Prob=0.8779, Pred=1, True=0
# 1243.mp4 → Prob=0.3588, Pred=0, True=0
# 1246.mp4 → Prob=0.7418, Pred=1, True=0
# 1247.mp4 → Prob=0.9686, Pred=1, True=0
# 1249.mp4 → Prob=0.5871, Pred=1, True=0
# 1255.mp4 → Prob=0.2908, Pred=0, True=0
# 1258.mp4 → Prob=0.2869, Pred=0, True=0
# 1259.mp4 → Prob=0.2896, Pred=0, True=0
# 1261.mp4 → Prob=0.3283, Pred=0, True=0
# 1266.mp4 → Prob=0.6550, Pred=1, True=0
# 1268.mp4 → Prob=0.6425, Pred=1, True=0
# 1271.mp4 → Prob=0.8375, Pred=1, True=0
# 1272.mp4 → Prob=0.7246, Pred=1, True=0
# 1276.mp4 → Prob=0.7071, Pred=1, True=0
# 1282.mp4 → Prob=0.6394, Pred=1, True=0
# 1284.mp4 → Prob=0.8395, Pred=1, True=0
# 1287.mp4 → Prob=0.8270, Pred=1, True=0
# 1291.mp4 → Prob=0.1077, Pred=0, True=0
# 1295.mp4 → Prob=0.5720, Pred=1, True=0
# 1298.mp4 → Prob=0.4234, Pred=0, True=0
# 1299.mp4 → Prob=0.5032, Pred=1, True=0
# 1305.mp4 → Prob=0.2504, Pred=0, True=0
# 1310.mp4 → Prob=0.5610, Pred=1, True=0
# 1311.mp4 → Prob=0.3660, Pred=0, True=0
# 1316.mp4 → Prob=0.2202, Pred=0, True=0
# 132.mp4 → Prob=0.6268, Pred=1, True=0
# 1327.mp4 → Prob=0.7130, Pred=1, True=0
# 1332.mp4 → Prob=0.3014, Pred=0, True=0
# 1334.mp4 → Prob=0.5673, Pred=1, True=0
# 1335.mp4 → Prob=0.2125, Pred=0, True=0
# 1338.mp4 → Prob=0.8844, Pred=1, True=0
# 1340.mp4 → Prob=0.0432, Pred=0, True=0
# 1346.mp4 → Prob=0.8125, Pred=1, True=0
# 1348.mp4 → Prob=0.5958, Pred=1, True=0
# 1355.mp4 → Prob=0.4293, Pred=0, True=0
# 1379.mp4 → Prob=0.8498, Pred=1, True=0
# 1387.mp4 → Prob=0.3257, Pred=0, True=0
# 139.mp4 → Prob=0.1265, Pred=0, True=0
# 1391.mp4 → Prob=0.3723, Pred=0, True=0
# 1392.mp4 → Prob=0.3651, Pred=0, True=0
# 1393.mp4 → Prob=0.9272, Pred=1, True=0
# 1402.mp4 → Prob=0.7706, Pred=1, True=0
# 1405.mp4 → Prob=0.5471, Pred=1, True=0
# 1408.mp4 → Prob=0.2291, Pred=0, True=0
# 1414.mp4 → Prob=0.6567, Pred=1, True=0
# 1426.mp4 → Prob=0.6513, Pred=1, True=0
# 1429.mp4 → Prob=0.8464, Pred=1, True=0
# 1439.mp4 → Prob=0.6099, Pred=1, True=0
# 1440.mp4 → Prob=0.4626, Pred=0, True=0
# 1442.mp4 → Prob=0.7248, Pred=1, True=0
# 1451.mp4 → Prob=0.0933, Pred=0, True=0
# 1455.mp4 → Prob=0.6612, Pred=1, True=0
# 1462.mp4 → Prob=0.6053, Pred=1, True=0
# 1471.mp4 → Prob=0.5164, Pred=1, True=0
# 1474.mp4 → Prob=0.3861, Pred=0, True=0
# 1481.mp4 → Prob=0.1409, Pred=0, True=0
# 149.mp4 → Prob=0.5206, Pred=1, True=0
# 1495.mp4 → Prob=0.5749, Pred=1, True=0
# 1496.mp4 → Prob=0.5606, Pred=1, True=0
# 1499.mp4 → Prob=0.4626, Pred=0, True=0
# 15.mp4 → Prob=0.9123, Pred=1, True=0
# 1502.mp4 → Prob=0.5637, Pred=1, True=0
# 1506.mp4 → Prob=0.7662, Pred=1, True=0
# 1511.mp4 → Prob=0.3290, Pred=0, True=0
# 1512.mp4 → Prob=0.7071, Pred=1, True=0
# 1514.mp4 → Prob=0.5663, Pred=1, True=0
# 1517.mp4 → Prob=0.3321, Pred=0, True=0
# 1519.mp4 → Prob=0.5712, Pred=1, True=0
# 1525.mp4 → Prob=0.1719, Pred=0, True=0
# 1527.mp4 → Prob=0.0434, Pred=0, True=0
# 153.mp4 → Prob=0.1408, Pred=0, True=0
# 1530.mp4 → Prob=0.2736, Pred=0, True=0
# 1536.mp4 → Prob=0.7220, Pred=1, True=0
# 1537.mp4 → Prob=0.2426, Pred=0, True=0
# 1545.mp4 → Prob=0.8392, Pred=1, True=0
# 1548.mp4 → Prob=0.9127, Pred=1, True=0
# 1558.mp4 → Prob=0.6735, Pred=1, True=0
# 1560.mp4 → Prob=0.4693, Pred=0, True=0
# 1561.mp4 → Prob=0.9043, Pred=1, True=0
# 1563.mp4 → Prob=0.3389, Pred=0, True=0
# 1566.mp4 → Prob=0.4509, Pred=0, True=0
# 1571.mp4 → Prob=0.5583, Pred=1, True=0
# 158.mp4 → Prob=0.5318, Pred=1, True=0
# 1586.mp4 → Prob=0.3629, Pred=0, True=0
# 1589.mp4 → Prob=0.8322, Pred=1, True=0
# 159.mp4 → Prob=0.8556, Pred=1, True=0
# 1595.mp4 → Prob=0.6857, Pred=1, True=0
# 160.mp4 → Prob=0.3608, Pred=0, True=0
# 1600.mp4 → Prob=0.3109, Pred=0, True=0
# 1613.mp4 → Prob=0.3893, Pred=0, True=0
# 1616.mp4 → Prob=0.7736, Pred=1, True=0
# 162.mp4 → Prob=0.5822, Pred=1, True=0
# 1631.mp4 → Prob=0.1841, Pred=0, True=0
# 1632.mp4 → Prob=0.5564, Pred=1, True=0
# 1634.mp4 → Prob=0.3057, Pred=0, True=0
# 1638.mp4 → Prob=0.3373, Pred=0, True=0
# 1643.mp4 → Prob=0.3854, Pred=0, True=0
# 1648.mp4 → Prob=0.7413, Pred=1, True=0
# 1662.mp4 → Prob=0.7640, Pred=1, True=0
# 1673.mp4 → Prob=0.5543, Pred=1, True=0
# 1677.mp4 → Prob=0.4941, Pred=0, True=0
# 1678.mp4 → Prob=0.7774, Pred=1, True=0
# 1682.mp4 → Prob=0.8071, Pred=1, True=0
# 1685.mp4 → Prob=0.3236, Pred=0, True=0
# 1686.mp4 → Prob=0.5234, Pred=1, True=0
# 169.mp4 → Prob=0.4834, Pred=0, True=0
# 17.mp4 → Prob=0.5325, Pred=1, True=0
# 1700.mp4 → Prob=0.2383, Pred=0, True=0
# 1708.mp4 → Prob=0.6606, Pred=1, True=0
# 1709.mp4 → Prob=0.7589, Pred=1, True=0
# 1723.mp4 → Prob=0.5951, Pred=1, True=0
# 174.mp4 → Prob=0.3112, Pred=0, True=0
# 1744.mp4 → Prob=0.5705, Pred=1, True=0
# 1745.mp4 → Prob=0.9182, Pred=1, True=0
# 1747.mp4 → Prob=0.9242, Pred=1, True=0
# 1753.mp4 → Prob=0.6886, Pred=1, True=0
# 1755.mp4 → Prob=0.5546, Pred=1, True=0
# 1759.mp4 → Prob=0.7461, Pred=1, True=0
# 1764.mp4 → Prob=0.2632, Pred=0, True=0
# 178.mp4 → Prob=0.6369, Pred=1, True=0
# 1780.mp4 → Prob=0.3385, Pred=0, True=0
# 1784.mp4 → Prob=0.3509, Pred=0, True=0
# 1792.mp4 → Prob=0.1659, Pred=0, True=0
# 1793.mp4 → Prob=0.3000, Pred=0, True=0
# 1798.mp4 → Prob=0.4824, Pred=0, True=0
# 1800.mp4 → Prob=0.2662, Pred=0, True=0
# 1806.mp4 → Prob=0.3032, Pred=0, True=0
# 1819.mp4 → Prob=0.7995, Pred=1, True=0
# 1830.mp4 → Prob=0.2368, Pred=0, True=0
# 1836.mp4 → Prob=0.7664, Pred=1, True=0
# 184.mp4 → Prob=0.7203, Pred=1, True=0
# 1846.mp4 → Prob=0.2892, Pred=0, True=0
# 1847.mp4 → Prob=0.1442, Pred=0, True=0
# 1853.mp4 → Prob=0.7180, Pred=1, True=0
# 186.mp4 → Prob=0.7488, Pred=1, True=0
# 1861.mp4 → Prob=0.5254, Pred=1, True=0
# 1864.mp4 → Prob=0.6047, Pred=1, True=0
# 1867.mp4 → Prob=0.4257, Pred=0, True=0
# 187.mp4 → Prob=0.7013, Pred=1, True=0
# 1878.mp4 → Prob=0.7341, Pred=1, True=0
# 188.mp4 → Prob=0.5421, Pred=1, True=0
# 1883.mp4 → Prob=0.8878, Pred=1, True=0
# 1885.mp4 → Prob=0.4937, Pred=0, True=0
# 190.mp4 → Prob=0.2099, Pred=0, True=0
# 201.mp4 → Prob=0.4644, Pred=0, True=0
# 202.mp4 → Prob=0.6817, Pred=1, True=0
# 206.mp4 → Prob=0.4034, Pred=0, True=0
# 21.mp4 → Prob=0.7136, Pred=1, True=0
# 212.mp4 → Prob=0.7013, Pred=1, True=0
# 214.mp4 → Prob=0.3311, Pred=0, True=0
# 215.mp4 → Prob=0.7195, Pred=1, True=0
# 224.mp4 → Prob=0.8626, Pred=1, True=0
# 226.mp4 → Prob=0.3182, Pred=0, True=0
# 228.mp4 → Prob=0.8459, Pred=1, True=0
# 23.mp4 → Prob=0.8965, Pred=1, True=0
# 234.mp4 → Prob=0.5805, Pred=1, True=0
# 235.mp4 → Prob=0.6001, Pred=1, True=0
# 237.mp4 → Prob=0.8490, Pred=1, True=0
# 250.mp4 → Prob=0.7749, Pred=1, True=0
# 266.mp4 → Prob=0.2048, Pred=0, True=0
# 271.mp4 → Prob=0.9140, Pred=1, True=0
# 278.mp4 → Prob=0.0772, Pred=0, True=0
# 286.mp4 → Prob=0.5100, Pred=1, True=0
# 289.mp4 → Prob=0.5642, Pred=1, True=0
# 293.mp4 → Prob=0.6492, Pred=1, True=0
# 297.mp4 → Prob=0.5727, Pred=1, True=0
# 300.mp4 → Prob=0.8765, Pred=1, True=0
# 302.mp4 → Prob=0.1719, Pred=0, True=0
# 303.mp4 → Prob=0.3470, Pred=0, True=0
# 311.mp4 → Prob=0.3072, Pred=0, True=0
# 315.mp4 → Prob=0.2714, Pred=0, True=0
# 318.mp4 → Prob=0.9174, Pred=1, True=0
# 320.mp4 → Prob=0.8829, Pred=1, True=0
# 330.mp4 → Prob=0.0476, Pred=0, True=0
# 338.mp4 → Prob=0.3128, Pred=0, True=0
# 34.mp4 → Prob=0.6363, Pred=1, True=0
# 342.mp4 → Prob=0.7442, Pred=1, True=0
# 358.mp4 → Prob=0.7787, Pred=1, True=0
# 364.mp4 → Prob=0.3358, Pred=0, True=0
# 368.mp4 → Prob=0.5127, Pred=1, True=0
# 370.mp4 → Prob=0.3384, Pred=0, True=0
# 377.mp4 → Prob=0.4116, Pred=0, True=0
# 378.mp4 → Prob=0.3443, Pred=0, True=0
# 38.mp4 → Prob=0.3798, Pred=0, True=0
# 381.mp4 → Prob=0.4353, Pred=0, True=0
# 387.mp4 → Prob=0.6220, Pred=1, True=0
# 397.mp4 → Prob=0.8344, Pred=1, True=0
# 4.mp4 → Prob=0.6808, Pred=1, True=0
# 400.mp4 → Prob=0.0792, Pred=0, True=0
# 404.mp4 → Prob=0.4478, Pred=0, True=0
# 406.mp4 → Prob=0.6143, Pred=1, True=0
# 410.mp4 → Prob=0.7216, Pred=1, True=0
# 411.mp4 → Prob=0.5167, Pred=1, True=0
# 412.mp4 → Prob=0.5369, Pred=1, True=0
# 437.mp4 → Prob=0.6335, Pred=1, True=0
# 450.mp4 → Prob=0.9282, Pred=1, True=0
# 460.mp4 → Prob=0.7216, Pred=1, True=0
# 466.mp4 → Prob=0.2086, Pred=0, True=0
# 47.mp4 → Prob=0.7668, Pred=1, True=0
# 474.mp4 → Prob=0.3358, Pred=0, True=0
# 479.mp4 → Prob=0.4859, Pred=0, True=0
# 482.mp4 → Prob=0.7899, Pred=1, True=0
# 486.mp4 → Prob=0.6606, Pred=1, True=0
# 488.mp4 → Prob=0.5218, Pred=1, True=0
# 49.mp4 → Prob=0.8514, Pred=1, True=0
# 496.mp4 → Prob=0.9123, Pred=1, True=0
# 500.mp4 → Prob=0.2251, Pred=0, True=0
# 507.mp4 → Prob=0.5685, Pred=1, True=0
# 51.mp4 → Prob=0.4057, Pred=0, True=0
# 510.mp4 → Prob=0.4088, Pred=0, True=0
# 516.mp4 → Prob=0.7472, Pred=1, True=0
# 522.mp4 → Prob=0.5189, Pred=1, True=0
# 523.mp4 → Prob=0.6857, Pred=1, True=0
# 527.mp4 → Prob=0.5497, Pred=1, True=0
# 528.mp4 → Prob=0.7703, Pred=1, True=0
# 537.mp4 → Prob=0.4949, Pred=0, True=0
# 539.mp4 → Prob=0.9737, Pred=1, True=0
# 542.mp4 → Prob=0.7412, Pred=1, True=0
# 545.mp4 → Prob=0.7612, Pred=1, True=0
# 552.mp4 → Prob=0.7716, Pred=1, True=0
# 566.mp4 → Prob=0.5002, Pred=1, True=0
# 567.mp4 → Prob=0.3551, Pred=0, True=0
# 569.mp4 → Prob=0.3100, Pred=0, True=0
# 57.mp4 → Prob=0.3425, Pred=0, True=0
# 574.mp4 → Prob=0.3386, Pred=0, True=0
# 578.mp4 → Prob=0.7986, Pred=1, True=0
# 581.mp4 → Prob=0.5724, Pred=1, True=0
# 586.mp4 → Prob=0.8384, Pred=1, True=0
# 592.mp4 → Prob=0.1597, Pred=0, True=0
# 60.mp4 → Prob=0.7136, Pred=1, True=0
# 607.mp4 → Prob=0.7584, Pred=1, True=0
# 616.mp4 → Prob=0.1709, Pred=0, True=0
# 62.mp4 → Prob=0.4911, Pred=0, True=0
# 621.mp4 → Prob=0.8744, Pred=1, True=0
# 626.mp4 → Prob=0.4996, Pred=0, True=0
# 634.mp4 → Prob=0.6822, Pred=1, True=0
# 638.mp4 → Prob=0.6573, Pred=1, True=0
# 64.mp4 → Prob=0.7874, Pred=1, True=0
# 647.mp4 → Prob=0.4507, Pred=0, True=0
# 648.mp4 → Prob=0.6623, Pred=1, True=0
# 659.mp4 → Prob=0.0962, Pred=0, True=0
# 660.mp4 → Prob=0.5853, Pred=1, True=0
# 661.mp4 → Prob=0.5614, Pred=1, True=0
# 666.mp4 → Prob=0.8967, Pred=1, True=0
# 672.mp4 → Prob=0.6989, Pred=1, True=0
# 677.mp4 → Prob=0.2136, Pred=0, True=0
# 680.mp4 → Prob=0.3481, Pred=0, True=0
# 683.mp4 → Prob=0.4292, Pred=0, True=0
# 689.mp4 → Prob=0.2084, Pred=0, True=0
# 696.mp4 → Prob=0.4242, Pred=0, True=0
# 703.mp4 → Prob=0.5282, Pred=1, True=0
# 705.mp4 → Prob=0.5705, Pred=1, True=0
# 707.mp4 → Prob=0.6944, Pred=1, True=0
# 708.mp4 → Prob=0.2171, Pred=0, True=0
# 714.mp4 → Prob=0.4377, Pred=0, True=0
# 717.mp4 → Prob=0.7398, Pred=1, True=0
# 722.mp4 → Prob=0.6988, Pred=1, True=0
# 724.mp4 → Prob=0.7523, Pred=1, True=0
# 731.mp4 → Prob=0.8850, Pred=1, True=0
# 733.mp4 → Prob=0.8843, Pred=1, True=0
# 740.mp4 → Prob=0.5890, Pred=1, True=0
# 748.mp4 → Prob=0.4960, Pred=0, True=0
# 757.mp4 → Prob=0.4078, Pred=0, True=0
# 760.mp4 → Prob=0.6445, Pred=1, True=0
# 762.mp4 → Prob=0.3303, Pred=0, True=0
# 766.mp4 → Prob=0.6979, Pred=1, True=0
# 77.mp4 → Prob=0.6371, Pred=1, True=0
# 770.mp4 → Prob=0.1360, Pred=0, True=0
# 773.mp4 → Prob=0.6765, Pred=1, True=0
# 776.mp4 → Prob=0.2749, Pred=0, True=0
# 777.mp4 → Prob=0.8120, Pred=1, True=0
# 786.mp4 → Prob=0.4748, Pred=0, True=0
# 790.mp4 → Prob=0.8823, Pred=1, True=0
# 794.mp4 → Prob=0.4011, Pred=0, True=0
# 799.mp4 → Prob=0.7066, Pred=1, True=0
# 808.mp4 → Prob=0.5571, Pred=1, True=0
# 828.mp4 → Prob=0.4424, Pred=0, True=0
# 830.mp4 → Prob=0.7070, Pred=1, True=0
# 832.mp4 → Prob=0.2149, Pred=0, True=0
# 841.mp4 → Prob=0.4961, Pred=0, True=0
# 843.mp4 → Prob=0.9725, Pred=1, True=0
# 853.mp4 → Prob=0.6168, Pred=1, True=0
# 857.mp4 → Prob=0.3858, Pred=0, True=0
# 861.mp4 → Prob=0.6666, Pred=1, True=0
# 867.mp4 → Prob=0.3355, Pred=0, True=0
# 872.mp4 → Prob=0.5330, Pred=1, True=0
# 876.mp4 → Prob=0.3662, Pred=0, True=0
# 879.mp4 → Prob=0.6564, Pred=1, True=0
# 880.mp4 → Prob=0.2999, Pred=0, True=0
# 881.mp4 → Prob=0.5809, Pred=1, True=0
# 882.mp4 → Prob=0.6166, Pred=1, True=0
# 884.mp4 → Prob=0.3129, Pred=0, True=0
# 891.mp4 → Prob=0.7430, Pred=1, True=0
# 892.mp4 → Prob=0.6674, Pred=1, True=0
# 901.mp4 → Prob=0.1733, Pred=0, True=0
# 902.mp4 → Prob=0.3100, Pred=0, True=0
# 916.mp4 → Prob=0.2828, Pred=0, True=0
# 917.mp4 → Prob=0.2178, Pred=0, True=0
# 919.mp4 → Prob=0.4364, Pred=0, True=0
# 925.mp4 → Prob=0.3690, Pred=0, True=0
# 933.mp4 → Prob=0.3899, Pred=0, True=0
# 935.mp4 → Prob=0.7792, Pred=1, True=0
# 944.mp4 → Prob=0.8587, Pred=1, True=0
# 95.mp4 → Prob=0.8588, Pred=1, True=0
# 953.mp4 → Prob=0.6942, Pred=1, True=0
# 957.mp4 → Prob=0.6506, Pred=1, True=0
# 959.mp4 → Prob=0.3170, Pred=0, True=0
# 960.mp4 → Prob=0.5170, Pred=1, True=0
# 962.mp4 → Prob=0.6880, Pred=1, True=0
# 965.mp4 → Prob=0.8998, Pred=1, True=0
# 966.mp4 → Prob=0.3742, Pred=0, True=0
# 972.mp4 → Prob=0.4028, Pred=0, True=0
# 973.mp4 → Prob=0.8724, Pred=1, True=0
# 979.mp4 → Prob=0.7006, Pred=1, True=0
# 981.mp4 → Prob=0.5009, Pred=1, True=0
# 983.mp4 → Prob=0.7700, Pred=1, True=0
#
# === Evaluating /kaggle/input/liveness-detection-zalo-2022/public_test_2/public_test_2/videos ===
# 0.mp4 → Prob=0.1109, Pred=0, True=1
# 1.mp4 → Prob=0.7480, Pred=1, True=1
# 10.mp4 → Prob=0.9053, Pred=1, True=1
# 100.mp4 → Prob=0.6285, Pred=1, True=1
# 101.mp4 → Prob=0.5327, Pred=1, True=1
# 102.mp4 → Prob=0.8476, Pred=1, True=1
# 103.mp4 → Prob=0.3063, Pred=0, True=1
# 104.mp4 → Prob=0.8385, Pred=1, True=1
# 105.mp4 → Prob=0.1368, Pred=0, True=1
# 106.mp4 → Prob=0.2920, Pred=0, True=1
# 107.mp4 → Prob=0.5738, Pred=1, True=1
# 108.mp4 → Prob=0.6518, Pred=1, True=1
# 109.mp4 → Prob=0.2852, Pred=0, True=1
# 11.mp4 → Prob=0.5115, Pred=1, True=1
# 110.mp4 → Prob=0.7044, Pred=1, True=1
# 111.mp4 → Prob=0.9168, Pred=1, True=1
# 112.mp4 → Prob=0.8153, Pred=1, True=1
# 113.mp4 → Prob=0.5713, Pred=1, True=1
# 114.mp4 → Prob=0.8675, Pred=1, True=1
# 115.mp4 → Prob=0.7953, Pred=1, True=1
# 116.mp4 → Prob=0.2437, Pred=0, True=1
# 117.mp4 → Prob=0.6168, Pred=1, True=1
# 118.mp4 → Prob=0.5158, Pred=1, True=1
# 119.mp4 → Prob=0.8724, Pred=1, True=1
# 12.mp4 → Prob=0.6711, Pred=1, True=1
# 120.mp4 → Prob=0.6714, Pred=1, True=1
# 121.mp4 → Prob=0.5477, Pred=1, True=1
# 122.mp4 → Prob=0.3942, Pred=0, True=1
# 123.mp4 → Prob=0.4639, Pred=0, True=1
# 124.mp4 → Prob=0.6923, Pred=1, True=1
# 125.mp4 → Prob=0.3903, Pred=0, True=1
# 126.mp4 → Prob=0.8796, Pred=1, True=1
# 127.mp4 → Prob=0.8424, Pred=1, True=1
# 128.mp4 → Prob=0.4805, Pred=0, True=1
# 129.mp4 → Prob=0.6881, Pred=1, True=1
# 13.mp4 → Prob=0.7287, Pred=1, True=1
# 130.mp4 → Prob=0.8429, Pred=1, True=1
# 131.mp4 → Prob=0.4601, Pred=0, True=1
# 132.mp4 → Prob=0.7513, Pred=1, True=1
# 133.mp4 → Prob=0.5906, Pred=1, True=1
# 134.mp4 → Prob=0.3831, Pred=0, True=1
# 135.mp4 → Prob=0.3399, Pred=0, True=1
# 136.mp4 → Prob=0.9059, Pred=1, True=1
# 137.mp4 → Prob=0.5701, Pred=1, True=1
# 138.mp4 → Prob=0.2246, Pred=0, True=1
# 139.mp4 → Prob=0.3454, Pred=0, True=1
# 14.mp4 → Prob=0.6033, Pred=1, True=1
# 140.mp4 → Prob=0.1871, Pred=0, True=1
# 141.mp4 → Prob=0.1985, Pred=0, True=1
# 142.mp4 → Prob=0.3040, Pred=0, True=1
# 143.mp4 → Prob=0.6669, Pred=1, True=1
# 144.mp4 → Prob=0.3108, Pred=0, True=1
# 145.mp4 → Prob=0.4403, Pred=0, True=1
# 146.mp4 → Prob=0.4635, Pred=0, True=1
# 147.mp4 → Prob=0.6791, Pred=1, True=1
# 148.mp4 → Prob=0.9457, Pred=1, True=1
# 149.mp4 → Prob=0.3881, Pred=0, True=1
# 15.mp4 → Prob=0.3721, Pred=0, True=1
# 150.mp4 → Prob=0.5111, Pred=1, True=1
# 151.mp4 → Prob=0.3593, Pred=0, True=1
# 152.mp4 → Prob=0.3264, Pred=0, True=1
# 153.mp4 → Prob=0.7309, Pred=1, True=1
# 154.mp4 → Prob=0.1643, Pred=0, True=1
# 155.mp4 → Prob=0.4778, Pred=0, True=1
# 156.mp4 → Prob=0.2167, Pred=0, True=1
# 157.mp4 → Prob=0.4649, Pred=0, True=1
# 158.mp4 → Prob=0.4801, Pred=0, True=1
# 159.mp4 → Prob=0.7543, Pred=1, True=1
# 16.mp4 → Prob=0.5973, Pred=1, True=1
# 160.mp4 → Prob=0.7939, Pred=1, True=1
# 161.mp4 → Prob=0.3310, Pred=0, True=1
# 162.mp4 → Prob=0.1456, Pred=0, True=1
# 163.mp4 → Prob=0.6461, Pred=1, True=1
# 164.mp4 → Prob=0.7404, Pred=1, True=1
# 165.mp4 → Prob=0.9267, Pred=1, True=1
# 166.mp4 → Prob=0.1416, Pred=0, True=1
# 167.mp4 → Prob=0.2097, Pred=0, True=1
# 168.mp4 → Prob=0.6538, Pred=1, True=1
# 169.mp4 → Prob=0.5427, Pred=1, True=1
# 17.mp4 → Prob=0.5508, Pred=1, True=1
# 170.mp4 → Prob=0.1084, Pred=0, True=1
# 171.mp4 → Prob=0.9186, Pred=1, True=1
# 172.mp4 → Prob=0.4182, Pred=0, True=1
# 173.mp4 → Prob=0.3801, Pred=0, True=1
# 174.mp4 → Prob=0.7051, Pred=1, True=1
# 175.mp4 → Prob=0.6368, Pred=1, True=1
# 176.mp4 → Prob=0.6879, Pred=1, True=1
# 177.mp4 → Prob=0.8922, Pred=1, True=1
# 178.mp4 → Prob=0.3251, Pred=0, True=1
# 179.mp4 → Prob=0.3542, Pred=0, True=1
# 18.mp4 → Prob=0.5831, Pred=1, True=1
# 180.mp4 → Prob=0.5563, Pred=1, True=1
# 181.mp4 → Prob=0.5744, Pred=1, True=1
# 182.mp4 → Prob=0.8638, Pred=1, True=1
# 183.mp4 → Prob=0.5226, Pred=1, True=1
# 184.mp4 → Prob=0.1700, Pred=0, True=1
# 185.mp4 → Prob=0.0996, Pred=0, True=1
# 186.mp4 → Prob=0.2602, Pred=0, True=1
# 187.mp4 → Prob=0.4843, Pred=0, True=1
# 188.mp4 → Prob=0.0826, Pred=0, True=1
# 189.mp4 → Prob=0.7308, Pred=1, True=1
# 19.mp4 → Prob=0.4061, Pred=0, True=1
# 190.mp4 → Prob=0.5915, Pred=1, True=1
# 191.mp4 → Prob=0.2458, Pred=0, True=1
# 192.mp4 → Prob=0.1007, Pred=0, True=1
# 193.mp4 → Prob=0.7516, Pred=1, True=1
# 194.mp4 → Prob=0.3116, Pred=0, True=1
# 195.mp4 → Prob=0.2927, Pred=0, True=1
# 196.mp4 → Prob=0.7605, Pred=1, True=1
# 197.mp4 → Prob=0.6972, Pred=1, True=1
# 198.mp4 → Prob=0.5027, Pred=1, True=1
# 199.mp4 → Prob=0.4229, Pred=0, True=1
# 2.mp4 → Prob=0.1495, Pred=0, True=1
# 20.mp4 → Prob=0.3465, Pred=0, True=1
# 200.mp4 → Prob=0.6906, Pred=1, True=1
# 201.mp4 → Prob=0.6795, Pred=1, True=1
# 202.mp4 → Prob=0.7636, Pred=1, True=1
# 203.mp4 → Prob=0.5599, Pred=1, True=1
# 204.mp4 → Prob=0.3422, Pred=0, True=1
# 205.mp4 → Prob=0.8666, Pred=1, True=1
# 206.mp4 → Prob=0.3839, Pred=0, True=1
# 207.mp4 → Prob=0.7225, Pred=1, True=1
# 208.mp4 → Prob=0.7876, Pred=1, True=1
# 209.mp4 → Prob=0.5245, Pred=1, True=1
# 21.mp4 → Prob=0.8760, Pred=1, True=1
# 210.mp4 → Prob=0.2631, Pred=0, True=1
# 211.mp4 → Prob=0.1440, Pred=0, True=1
# 212.mp4 → Prob=0.9110, Pred=1, True=1
# 213.mp4 → Prob=0.8611, Pred=1, True=1
# 214.mp4 → Prob=0.6986, Pred=1, True=1
# 215.mp4 → Prob=0.8530, Pred=1, True=1
# 216.mp4 → Prob=0.4705, Pred=0, True=1
# 217.mp4 → Prob=0.9479, Pred=1, True=1
# 218.mp4 → Prob=0.4971, Pred=0, True=1
# 219.mp4 → Prob=0.2434, Pred=0, True=1
# 22.mp4 → Prob=0.7781, Pred=1, True=1
# 220.mp4 → Prob=0.5282, Pred=1, True=1
# 221.mp4 → Prob=0.3762, Pred=0, True=1
# 222.mp4 → Prob=0.3099, Pred=0, True=1
# 223.mp4 → Prob=0.5211, Pred=1, True=1
# 224.mp4 → Prob=0.7694, Pred=1, True=1
# 225.mp4 → Prob=0.6537, Pred=1, True=1
# 226.mp4 → Prob=0.3944, Pred=0, True=1
# 227.mp4 → Prob=0.3694, Pred=0, True=1
# 228.mp4 → Prob=0.8934, Pred=1, True=1
# 229.mp4 → Prob=0.8596, Pred=1, True=1
# 23.mp4 → Prob=0.3585, Pred=0, True=1
# 230.mp4 → Prob=0.3955, Pred=0, True=1
# 231.mp4 → Prob=0.8399, Pred=1, True=1
# 232.mp4 → Prob=0.3679, Pred=0, True=1
# 233.mp4 → Prob=0.8758, Pred=1, True=1
# 234.mp4 → Prob=0.2610, Pred=0, True=1
# 235.mp4 → Prob=0.5960, Pred=1, True=1
# 236.mp4 → Prob=0.1996, Pred=0, True=1
# 237.mp4 → Prob=0.5080, Pred=1, True=1
# 238.mp4 → Prob=0.4287, Pred=0, True=1
# 239.mp4 → Prob=0.0894, Pred=0, True=1
# 24.mp4 → Prob=0.4514, Pred=0, True=1
# 240.mp4 → Prob=0.6680, Pred=1, True=1
# 241.mp4 → Prob=0.5129, Pred=1, True=1
# 242.mp4 → Prob=0.4476, Pred=0, True=1
# 243.mp4 → Prob=0.5115, Pred=1, True=1
# 244.mp4 → Prob=0.2486, Pred=0, True=1
# 245.mp4 → Prob=0.6995, Pred=1, True=1
# 246.mp4 → Prob=0.4561, Pred=0, True=1
# 247.mp4 → Prob=0.3616, Pred=0, True=1
# 248.mp4 → Prob=0.9051, Pred=1, True=1
# 249.mp4 → Prob=0.3471, Pred=0, True=1
# 25.mp4 → Prob=0.2287, Pred=0, True=1
# 250.mp4 → Prob=0.1100, Pred=0, True=1
# 251.mp4 → Prob=0.1419, Pred=0, True=1
# 252.mp4 → Prob=0.4937, Pred=0, True=1
# 253.mp4 → Prob=0.6851, Pred=1, True=1
# 254.mp4 → Prob=0.7086, Pred=1, True=1
# 255.mp4 → Prob=0.3861, Pred=0, True=1
# 256.mp4 → Prob=0.1033, Pred=0, True=1
# 257.mp4 → Prob=0.8826, Pred=1, True=1
# 258.mp4 → Prob=0.5755, Pred=1, True=1
# 259.mp4 → Prob=0.3268, Pred=0, True=1
# 26.mp4 → Prob=0.8032, Pred=1, True=1
# 260.mp4 → Prob=0.8620, Pred=1, True=1
# 261.mp4 → Prob=0.1895, Pred=0, True=1
# 262.mp4 → Prob=0.4256, Pred=0, True=1
# 263.mp4 → Prob=0.8057, Pred=1, True=1
# 264.mp4 → Prob=0.8767, Pred=1, True=1
# 265.mp4 → Prob=0.4503, Pred=0, True=1
# 266.mp4 → Prob=0.2121, Pred=0, True=1
# 267.mp4 → Prob=0.5862, Pred=1, True=1
# 268.mp4 → Prob=0.8393, Pred=1, True=1
# 269.mp4 → Prob=0.4526, Pred=0, True=1
# 27.mp4 → Prob=0.3324, Pred=0, True=1
# 270.mp4 → Prob=0.2455, Pred=0, True=1
# 271.mp4 → Prob=0.3720, Pred=0, True=1
# 272.mp4 → Prob=0.9270, Pred=1, True=1
# 273.mp4 → Prob=0.5233, Pred=1, True=1
# 274.mp4 → Prob=0.2514, Pred=0, True=1
# 275.mp4 → Prob=0.4589, Pred=0, True=1
# 276.mp4 → Prob=0.8055, Pred=1, True=1
# 277.mp4 → Prob=0.3315, Pred=0, True=1
# 278.mp4 → Prob=0.6975, Pred=1, True=1
# 279.mp4 → Prob=0.7572, Pred=1, True=1
# 28.mp4 → Prob=0.8635, Pred=1, True=1
# 280.mp4 → Prob=0.9313, Pred=1, True=1
# 281.mp4 → Prob=0.1194, Pred=0, True=1
# 282.mp4 → Prob=0.8363, Pred=1, True=1
# 283.mp4 → Prob=0.6498, Pred=1, True=1
# 284.mp4 → Prob=0.1697, Pred=0, True=1
# 285.mp4 → Prob=0.7362, Pred=1, True=1
# 286.mp4 → Prob=0.0531, Pred=0, True=1
# 287.mp4 → Prob=0.7546, Pred=1, True=1
# 288.mp4 → Prob=0.7613, Pred=1, True=1
# 289.mp4 → Prob=0.7650, Pred=1, True=1
# 29.mp4 → Prob=0.7304, Pred=1, True=1
# 290.mp4 → Prob=0.7675, Pred=1, True=1
# 291.mp4 → Prob=0.3599, Pred=0, True=1
# 292.mp4 → Prob=0.3629, Pred=0, True=1
# 293.mp4 → Prob=0.4704, Pred=0, True=1
# 294.mp4 → Prob=0.6112, Pred=1, True=1
# 295.mp4 → Prob=0.2689, Pred=0, True=1
# 296.mp4 → Prob=0.5122, Pred=1, True=1
# 297.mp4 → Prob=0.4942, Pred=0, True=1
# 298.mp4 → Prob=0.7542, Pred=1, True=1
# 299.mp4 → Prob=0.1132, Pred=0, True=1
# 3.mp4 → Prob=0.8241, Pred=1, True=1
# 30.mp4 → Prob=0.8622, Pred=1, True=1
# 300.mp4 → Prob=0.8768, Pred=1, True=1
# 301.mp4 → Prob=0.3846, Pred=0, True=1
# 302.mp4 → Prob=0.9423, Pred=1, True=1
# 303.mp4 → Prob=0.6679, Pred=1, True=1
# 304.mp4 → Prob=0.9522, Pred=1, True=1
# 305.mp4 → Prob=0.7898, Pred=1, True=1
# 306.mp4 → Prob=0.8889, Pred=1, True=1
# 307.mp4 → Prob=0.3697, Pred=0, True=1
# 308.mp4 → Prob=0.8611, Pred=1, True=1
# 309.mp4 → Prob=0.7005, Pred=1, True=1
# 31.mp4 → Prob=0.5895, Pred=1, True=1
# 310.mp4 → Prob=0.1938, Pred=0, True=1
# 311.mp4 → Prob=0.7675, Pred=1, True=1
# 312.mp4 → Prob=0.6280, Pred=1, True=1
# 313.mp4 → Prob=0.4758, Pred=0, True=1
# 314.mp4 → Prob=0.6215, Pred=1, True=1
# 315.mp4 → Prob=0.5067, Pred=1, True=1
# 316.mp4 → Prob=0.9444, Pred=1, True=1
# 317.mp4 → Prob=0.8861, Pred=1, True=1
# 318.mp4 → Prob=0.2768, Pred=0, True=1
# 319.mp4 → Prob=0.3724, Pred=0, True=1
# 32.mp4 → Prob=0.2494, Pred=0, True=1
# 320.mp4 → Prob=0.3314, Pred=0, True=1
# 321.mp4 → Prob=0.5602, Pred=1, True=1
# 322.mp4 → Prob=0.7025, Pred=1, True=1
# 323.mp4 → Prob=0.6154, Pred=1, True=1
# 324.mp4 → Prob=0.4114, Pred=0, True=1
# 325.mp4 → Prob=0.3118, Pred=0, True=1
# 326.mp4 → Prob=0.3439, Pred=0, True=1
# 327.mp4 → Prob=0.3789, Pred=0, True=1
# 328.mp4 → Prob=0.4239, Pred=0, True=1
# 329.mp4 → Prob=0.7044, Pred=1, True=1
# 33.mp4 → Prob=0.7259, Pred=1, True=1
# 330.mp4 → Prob=0.2733, Pred=0, True=1
# 331.mp4 → Prob=0.6336, Pred=1, True=1
# 332.mp4 → Prob=0.6148, Pred=1, True=1
# 333.mp4 → Prob=0.6442, Pred=1, True=1
# 334.mp4 → Prob=0.1914, Pred=0, True=1
# 335.mp4 → Prob=0.7292, Pred=1, True=1
# 336.mp4 → Prob=0.8195, Pred=1, True=1
# 337.mp4 → Prob=0.7663, Pred=1, True=1
# 338.mp4 → Prob=0.1069, Pred=0, True=1
# 339.mp4 → Prob=0.5927, Pred=1, True=1
# 34.mp4 → Prob=0.3881, Pred=0, True=1
# 340.mp4 → Prob=0.1977, Pred=0, True=1
# 341.mp4 → Prob=0.7980, Pred=1, True=1
# 342.mp4 → Prob=0.3160, Pred=0, True=1
# 343.mp4 → Prob=0.7894, Pred=1, True=1
# 344.mp4 → Prob=0.3943, Pred=0, True=1
# 345.mp4 → Prob=0.5322, Pred=1, True=1
# 346.mp4 → Prob=0.7493, Pred=1, True=1
# 347.mp4 → Prob=0.4069, Pred=0, True=1
# 348.mp4 → Prob=0.3264, Pred=0, True=1
# 349.mp4 → Prob=0.6343, Pred=1, True=1
# 35.mp4 → Prob=0.3504, Pred=0, True=1
# 350.mp4 → Prob=0.3333, Pred=0, True=1
# 351.mp4 → Prob=0.7189, Pred=1, True=1
# 352.mp4 → Prob=0.1729, Pred=0, True=1
# 353.mp4 → Prob=0.6243, Pred=1, True=1
# 354.mp4 → Prob=0.5935, Pred=1, True=1
# 355.mp4 → Prob=0.1479, Pred=0, True=1
# 356.mp4 → Prob=0.6715, Pred=1, True=1
# 357.mp4 → Prob=0.7306, Pred=1, True=1
# 358.mp4 → Prob=0.5889, Pred=1, True=1
# 359.mp4 → Prob=0.9194, Pred=1, True=1
# 36.mp4 → Prob=0.3347, Pred=0, True=1
# 360.mp4 → Prob=0.8894, Pred=1, True=1
# 361.mp4 → Prob=0.5270, Pred=1, True=1
# 362.mp4 → Prob=0.2856, Pred=0, True=1
# 363.mp4 → Prob=0.5111, Pred=1, True=1
# 364.mp4 → Prob=0.7795, Pred=1, True=1
# 365.mp4 → Prob=0.7778, Pred=1, True=1
# 366.mp4 → Prob=0.9069, Pred=1, True=1
# 367.mp4 → Prob=0.5164, Pred=1, True=1
# 368.mp4 → Prob=0.3550, Pred=0, True=1
# 369.mp4 → Prob=0.9162, Pred=1, True=1
# 37.mp4 → Prob=0.6114, Pred=1, True=1
# 370.mp4 → Prob=0.8091, Pred=1, True=1
# 371.mp4 → Prob=0.9718, Pred=1, True=1
# 372.mp4 → Prob=0.5441, Pred=1, True=1
# 373.mp4 → Prob=0.3553, Pred=0, True=1
# 374.mp4 → Prob=0.8876, Pred=1, True=1
# 375.mp4 → Prob=0.3536, Pred=0, True=1
# 376.mp4 → Prob=0.8020, Pred=1, True=1
# 377.mp4 → Prob=0.2384, Pred=0, True=1
# 378.mp4 → Prob=0.3399, Pred=0, True=1
# 379.mp4 → Prob=0.7778, Pred=1, True=1
# 38.mp4 → Prob=0.5326, Pred=1, True=1
# 380.mp4 → Prob=0.7458, Pred=1, True=1
# 381.mp4 → Prob=0.2879, Pred=0, True=1
# 382.mp4 → Prob=0.4908, Pred=0, True=1
# 383.mp4 → Prob=0.8423, Pred=1, True=1
# 384.mp4 → Prob=0.9502, Pred=1, True=1
# 385.mp4 → Prob=0.9112, Pred=1, True=1
# 386.mp4 → Prob=0.8245, Pred=1, True=1
# 387.mp4 → Prob=0.5545, Pred=1, True=1
# 388.mp4 → Prob=0.8109, Pred=1, True=1
# 389.mp4 → Prob=0.7740, Pred=1, True=1
# 39.mp4 → Prob=0.4018, Pred=0, True=1
# 390.mp4 → Prob=0.2640, Pred=0, True=1
# 391.mp4 → Prob=0.7639, Pred=1, True=1
# 392.mp4 → Prob=0.8032, Pred=1, True=1
# 393.mp4 → Prob=0.5042, Pred=1, True=1
# 394.mp4 → Prob=0.5222, Pred=1, True=1
# 395.mp4 → Prob=0.7270, Pred=1, True=1
# 396.mp4 → Prob=0.6653, Pred=1, True=1
# 397.mp4 → Prob=0.3987, Pred=0, True=1
# 398.mp4 → Prob=0.6433, Pred=1, True=1
# 399.mp4 → Prob=0.5757, Pred=1, True=1
# 4.mp4 → Prob=0.2820, Pred=0, True=1
# 40.mp4 → Prob=0.7176, Pred=1, True=1
# 400.mp4 → Prob=0.8852, Pred=1, True=1
# 401.mp4 → Prob=0.6747, Pred=1, True=1
# 402.mp4 → Prob=0.5136, Pred=1, True=1
# 403.mp4 → Prob=0.9088, Pred=1, True=1
# 404.mp4 → Prob=0.3731, Pred=0, True=1
# 405.mp4 → Prob=0.5496, Pred=1, True=1
# 406.mp4 → Prob=0.6670, Pred=1, True=1
# 407.mp4 → Prob=0.8127, Pred=1, True=1
# 408.mp4 → Prob=0.5868, Pred=1, True=1
# 409.mp4 → Prob=0.5336, Pred=1, True=1
# 41.mp4 → Prob=0.4497, Pred=0, True=1
# 410.mp4 → Prob=0.8881, Pred=1, True=1
# 411.mp4 → Prob=0.6495, Pred=1, True=1
# 412.mp4 → Prob=0.5775, Pred=1, True=1
# 413.mp4 → Prob=0.4909, Pred=0, True=1
# 414.mp4 → Prob=0.2952, Pred=0, True=1
# 415.mp4 → Prob=0.7432, Pred=1, True=1
# 416.mp4 → Prob=0.7991, Pred=1, True=1
# 417.mp4 → Prob=0.1519, Pred=0, True=1
# 418.mp4 → Prob=0.8250, Pred=1, True=1
# 419.mp4 → Prob=0.3211, Pred=0, True=1
# 42.mp4 → Prob=0.4752, Pred=0, True=1
# 420.mp4 → Prob=0.7476, Pred=1, True=1
# 421.mp4 → Prob=0.3120, Pred=0, True=1
# 422.mp4 → Prob=0.4622, Pred=0, True=1
# 423.mp4 → Prob=0.3388, Pred=0, True=1
# 424.mp4 → Prob=0.7338, Pred=1, True=1
# 425.mp4 → Prob=0.7701, Pred=1, True=1
# 426.mp4 → Prob=0.2423, Pred=0, True=1
# 427.mp4 → Prob=0.5153, Pred=1, True=1
# 428.mp4 → Prob=0.7256, Pred=1, True=1
# 429.mp4 → Prob=0.5916, Pred=1, True=1
# 43.mp4 → Prob=0.6817, Pred=1, True=1
# 430.mp4 → Prob=0.5330, Pred=1, True=1
# 431.mp4 → Prob=0.3732, Pred=0, True=1
# 432.mp4 → Prob=0.5278, Pred=1, True=1
# 433.mp4 → Prob=0.3081, Pred=0, True=1
# 434.mp4 → Prob=0.5418, Pred=1, True=1
# 435.mp4 → Prob=0.7956, Pred=1, True=1
# 436.mp4 → Prob=0.9404, Pred=1, True=1
# 437.mp4 → Prob=0.2731, Pred=0, True=1
# 438.mp4 → Prob=0.7213, Pred=1, True=1
# 439.mp4 → Prob=0.2651, Pred=0, True=1
# 44.mp4 → Prob=0.1566, Pred=0, True=1
# 440.mp4 → Prob=0.5459, Pred=1, True=1
# 441.mp4 → Prob=0.2991, Pred=0, True=1
# 442.mp4 → Prob=0.5348, Pred=1, True=1
# 443.mp4 → Prob=0.4027, Pred=0, True=1
# 444.mp4 → Prob=0.3541, Pred=0, True=1
# 445.mp4 → Prob=0.5403, Pred=1, True=1
# 446.mp4 → Prob=0.5512, Pred=1, True=1
# 447.mp4 → Prob=0.6944, Pred=1, True=1
# 448.mp4 → Prob=0.9660, Pred=1, True=1
# 449.mp4 → Prob=0.4770, Pred=0, True=1
# 45.mp4 → Prob=0.1778, Pred=0, True=1
# 450.mp4 → Prob=0.7916, Pred=1, True=1
# 451.mp4 → Prob=0.3897, Pred=0, True=1
# 452.mp4 → Prob=0.6355, Pred=1, True=1
# 453.mp4 → Prob=0.1555, Pred=0, True=1
# 454.mp4 → Prob=0.8169, Pred=1, True=1
# 455.mp4 → Prob=0.4794, Pred=0, True=1
# 456.mp4 → Prob=0.7415, Pred=1, True=1
# 457.mp4 → Prob=0.6650, Pred=1, True=1
# 458.mp4 → Prob=0.7846, Pred=1, True=1
# 459.mp4 → Prob=0.4047, Pred=0, True=1
# 46.mp4 → Prob=0.7509, Pred=1, True=1
# 460.mp4 → Prob=0.7153, Pred=1, True=1
# 461.mp4 → Prob=0.7359, Pred=1, True=1
# 462.mp4 → Prob=0.4119, Pred=0, True=1
# 463.mp4 → Prob=0.8230, Pred=1, True=1
# 464.mp4 → Prob=0.3038, Pred=0, True=1
# 465.mp4 → Prob=0.2484, Pred=0, True=1
# 466.mp4 → Prob=0.7566, Pred=1, True=1
# 467.mp4 → Prob=0.9088, Pred=1, True=1
# 468.mp4 → Prob=0.5360, Pred=1, True=1
# 469.mp4 → Prob=0.5946, Pred=1, True=1
# 47.mp4 → Prob=0.9139, Pred=1, True=1
# 470.mp4 → Prob=0.9053, Pred=1, True=1
# 471.mp4 → Prob=0.3149, Pred=0, True=1
# 472.mp4 → Prob=0.7749, Pred=1, True=1
# 473.mp4 → Prob=0.1145, Pred=0, True=1
# 474.mp4 → Prob=0.2305, Pred=0, True=1
# 475.mp4 → Prob=0.4460, Pred=0, True=1
# 476.mp4 → Prob=0.8523, Pred=1, True=1
# 477.mp4 → Prob=0.1262, Pred=0, True=1
# 478.mp4 → Prob=0.1434, Pred=0, True=1
# 479.mp4 → Prob=0.7863, Pred=1, True=1
# 48.mp4 → Prob=0.6550, Pred=1, True=1
# 480.mp4 → Prob=0.5542, Pred=1, True=1
# 481.mp4 → Prob=0.7577, Pred=1, True=1
# 482.mp4 → Prob=0.7891, Pred=1, True=1
# 483.mp4 → Prob=0.4323, Pred=0, True=1
# 484.mp4 → Prob=0.5903, Pred=1, True=1
# 485.mp4 → Prob=0.6107, Pred=1, True=1
# 49.mp4 → Prob=0.5219, Pred=1, True=1
# 5.mp4 → Prob=0.3101, Pred=0, True=1
# 50.mp4 → Prob=0.6196, Pred=1, True=1
# 51.mp4 → Prob=0.6542, Pred=1, True=1
# 52.mp4 → Prob=0.5198, Pred=1, True=1
# 53.mp4 → Prob=0.4393, Pred=0, True=1
# 54.mp4 → Prob=0.3906, Pred=0, True=1
# 55.mp4 → Prob=0.6382, Pred=1, True=1
# 56.mp4 → Prob=0.7740, Pred=1, True=1
# 57.mp4 → Prob=0.5706, Pred=1, True=1
# 58.mp4 → Prob=0.6777, Pred=1, True=1
# 59.mp4 → Prob=0.9046, Pred=1, True=1
# 6.mp4 → Prob=0.8355, Pred=1, True=1
# 60.mp4 → Prob=0.4334, Pred=0, True=1
# 61.mp4 → Prob=0.3535, Pred=0, True=1
# 62.mp4 → Prob=0.2197, Pred=0, True=1
# 63.mp4 → Prob=0.8786, Pred=1, True=1
# 64.mp4 → Prob=0.6763, Pred=1, True=1
# 65.mp4 → Prob=0.4549, Pred=0, True=1
# 66.mp4 → Prob=0.3191, Pred=0, True=1
# 67.mp4 → Prob=0.4999, Pred=0, True=1
# 68.mp4 → Prob=0.5895, Pred=1, True=1
# 69.mp4 → Prob=0.1720, Pred=0, True=1
# 7.mp4 → Prob=0.3510, Pred=0, True=1
# 70.mp4 → Prob=0.8159, Pred=1, True=1
# 71.mp4 → Prob=0.9615, Pred=1, True=1
# 72.mp4 → Prob=0.4786, Pred=0, True=1
# 73.mp4 → Prob=0.3173, Pred=0, True=1
# 74.mp4 → Prob=0.9041, Pred=1, True=1
# 75.mp4 → Prob=0.1395, Pred=0, True=1
# 76.mp4 → Prob=0.1933, Pred=0, True=1
# 77.mp4 → Prob=0.5968, Pred=1, True=1
# 78.mp4 → Prob=0.8826, Pred=1, True=1
# 79.mp4 → Prob=0.3136, Pred=0, True=1
# 8.mp4 → Prob=0.4451, Pred=0, True=1
# 80.mp4 → Prob=0.6679, Pred=1, True=1
# 81.mp4 → Prob=0.2612, Pred=0, True=1
# 82.mp4 → Prob=0.7766, Pred=1, True=1
# 83.mp4 → Prob=0.8192, Pred=1, True=1
# 84.mp4 → Prob=0.3333, Pred=0, True=1
# 85.mp4 → Prob=0.7569, Pred=1, True=1
# 86.mp4 → Prob=0.6653, Pred=1, True=1
# 87.mp4 → Prob=0.5789, Pred=1, True=1
# 88.mp4 → Prob=0.8553, Pred=1, True=1
# 89.mp4 → Prob=0.5007, Pred=1, True=1
# 9.mp4 → Prob=0.3556, Pred=0, True=1
# 90.mp4 → Prob=0.5915, Pred=1, True=1
# 91.mp4 → Prob=0.6733, Pred=1, True=1
# 92.mp4 → Prob=0.4862, Pred=0, True=1
# 93.mp4 → Prob=0.7601, Pred=1, True=1
# 94.mp4 → Prob=0.5306, Pred=1, True=1
# 95.mp4 → Prob=0.5801, Pred=1, True=1
# 96.mp4 → Prob=0.4674, Pred=0, True=1
# 97.mp4 → Prob=0.5045, Pred=1, True=1
# 98.mp4 → Prob=0.6964, Pred=1, True=1
# 99.mp4 → Prob=0.7787, Pred=1, True=1
#
# === Classification Report ===
#               precision    recall  f1-score   support
#
#         Fake       0.42      0.41      0.41       350
#         Real       0.58      0.59      0.59       486
#
#     accuracy                           0.51       836
#    macro avg       0.50      0.50      0.50       836
# weighted avg       0.51      0.51      0.51       836
#
#
# === Confusion Matrix ===
# [[143 207]
#  [199 287]]
