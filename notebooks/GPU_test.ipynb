# %%
# !nvidia-smi
# Out:
# Wed Nov  5 12:44:42 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 581.42                 Driver Version: 581.42         CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3050 ...  WDDM  |   00000000:01:00.0  On |                  N/A |
# | N/A   57C    P0             15W /   85W |    1024MiB /   4096MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            3728    C+G   ...xyewy\ShellExperienceHost.exe      N/A      |
# |    0   N/A  N/A            5392    C+G   ...2txyewy\CrossDeviceResume.exe      N/A      |
# |    0   N/A  N/A            9760    C+G   C:\Windows\explorer.exe               N/A      |
# |    0   N/A  N/A           10324    C+G   ...ntrolPanel\SystemSettings.exe      N/A      |
# |    0   N/A  N/A           11664    C+G   ...App_cw5n1h2txyewy\LockApp.exe      N/A      |
# |    0   N/A  N/A           11772    C+G   ..._cw5n1h2txyewy\SearchHost.exe      N/A      |
# |    0   N/A  N/A           12348    C+G   ....0.3537.99\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A           15296    C+G   ...e Experience\NVIDIA Share.exe      N/A      |
# |    0   N/A  N/A           16664    C+G   ...em32\ApplicationFrameHost.exe      N/A      |
# |    0   N/A  N/A           18548    C+G   ...indows\System32\ShellHost.exe      N/A      |
# |    0   N/A  N/A           19088    C+G   ...D\CNext\CNext\AMDRSSrcExt.exe      N/A      |
# |    0   N/A  N/A           19624    C+G   ...\plugins\capture\ZaloCall.exe      N/A      |
# |    0   N/A  N/A           21668    C+G   ...y\StartMenuExperienceHost.exe      N/A      |
# |    0   N/A  N/A           22712    C+G   ...ef.win7x64\steamwebhelper.exe      N/A      |
# |    0   N/A  N/A           22868    C+G   ...c\AdobeNotificationClient.exe      N/A      |
# |    0   N/A  N/A           22876    C+G   ...ms\Zalo\Zalo-25.10.2\Zalo.exe      N/A      |
# |    0   N/A  N/A           23872    C+G   ...5n1h2txyewy\TextInputHost.exe      N/A      |
# |    0   N/A  N/A           24896    C+G   ...e Experience\NVIDIA Share.exe      N/A      |
# |    0   N/A  N/A           24984    C+G   ...mba6cd70vzyy\ArmouryCrate.exe      N/A      |
# |    0   N/A  N/A           26656    C+G   ...ms\Microsoft VS Code\Code.exe      N/A      |
# |    0   N/A  N/A           28632    C+G   ...Next\CNext\RadeonSoftware.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
import tensorflow as tf
print("TensorFlow:", tf.__version__)
print("Built with CUDA:", tf.test.is_built_with_cuda())
print("GPU devices:", tf.config.list_physical_devices('GPU'))
# Out:
# WARNING:tensorflow:From d:\apply_ML\facial_recognition\.venv\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# TensorFlow: 2.15.0
# Built with CUDA: False
# GPU devices: []

# %%
from tensorflow.python.platform import build_info as tf_build_info
print(tf_build_info.build_info)
# Out:
# OrderedDict([('is_cuda_build', False), ('is_rocm_build', False), ('is_tensorrt_build', False), ('msvcp_dll_names', 'msvcp140.dll,msvcp140_1.dll')])
